# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.plot([1, 4, 9, 16, 8])

# %%
mpl.rc('font', family='Nanum Gothic')
mpl.rc('axes', unicode_minus=False)

# %%
plt.title("제목")
plt.plot([10, 20, 30, 40], [1, 7, 9, 16])
plt.show()

# %%
import numpy as np
x_data = np.array([10, 20, 30, 40])
y_data = np.array([1, 7, 9, 16])
plt.plot(x_data, y_data)

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 7, 9, 16])
plt.xlabel('엑스축 라벨')
plt.ylabel('와이축 라벨')
# Out:
# Text(0, 0.5, '와이축 라벨')

# %%
plt.title('title')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'r*-.')

# %%
X = np.linspace(-np.pi, np.pi, 100)
C = np.cos(X)
plt.title("x축과 y축의 tick label 설정")
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1, 0 ,1])
plt.show()

# %%
plt.title("Latex, 문자열로 tick label 정의")
plt.plot(X, C)

plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ['low', 'zero', 'high'])
plt.show()

# %%
plt.title("Latex, 문자열로 tick label 정의")
plt.plot(X, C)

plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ['low', 'zero', 'high'])
plt.grid(True)
plt.show()

# %%
t = np.arange(0., 5., 0.2)
plt.title("라인 프롯에 여러선 그리기")
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title('복수의 플롯 명령한 그림에서 표현')
plt.plot([1, 4, 9, 16], 'r--')
plt.plot([9, 16, 4, 1], 'bs:')
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title('legend를 표시한 플롯')
plt.plot(X, C,)

# %%
np.random.seed(2)
f1 = plt.figure(figsize=[10, 2])
plt.title('figure size: (10, 2)')
plt.plot(np.random.randn(100))
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x1)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('a tale of 2 subplots')
plt.ylabel('Damped osc')
print(ax1)

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.title('time s')
plt.ylabel('Undamped')
print(ax2)

plt.tight_layout()
plt.show()
# Out:
# Axes(0.125,0.53;0.775x0.35)
# Axes(0.125,0.11;0.775x0.35)

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()
