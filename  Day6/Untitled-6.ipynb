# %% [markdown]
# 과적합 피하기

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import tensorflow as tf
# Seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
df = pd.read_csv('data/sonar.csv', header=None)
df
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
dataset = df.values
X = dataset[:, :60].astype(float)
Y_obj = dataset[:, 60]

# %%
e = LabelEncoder()
e.fit(Y_obj)
Y=e.transform(Y_obj)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# 모델 실행

model.fit(X, Y, epochs=100, batch_size=5)
# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# Epoch 1/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 374us/step - accuracy: 0.5699 - loss: 0.6921
# Epoch 2/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step - accuracy: 0.6495 - loss: 0.6554
# Epoch 3/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 249us/step - accuracy: 0.6509 - loss: 0.6499
# Epoch 4/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 245us/step - accuracy: 0.6747 - loss: 0.6353
# Epoch 5/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 275us/step - accuracy: 0.6721 - loss: 0.6177
# Epoch 6/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 286us/step - accuracy: 0.6940 - loss: 0.5966
# Epoch 7/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 285us/step - accuracy: 0.6943 - loss: 0.5824
# Epoch 8/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 261us/step - accuracy: 0.7330 - loss: 0.5645
# Epoch 9/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - accuracy: 0.7408 - loss: 0.5472
# Epoch 10/100
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 290us/step - accuracy: 0.7467 - loss: 0.5316
# Epoch 11/100
# ...

# %% [markdown]
# 트레이닝셋과 테스트셋

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)
print("x_train.shape=", x_train.shape)
print("x_test.shape=", x_test.shape)
print("y_train.shape=", y_train.shape)
print("y_test-shape=", y_test.shape)
# Out:
# x_train.shape= (145, 60)
# x_test.shape= (63, 60)
# y_train.shape= (145,)
# y_test-shape= (63,)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(24, input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# 모델 실행

model.fit(x_train, y_train, epochs=100, batch_size=5)
# 결과 출력
print("\n Accuracy: %.4f" % (model.evaluate(x_test, y_test )[1]))
# Out:
# Epoch 1/100
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step - accuracy: 0.5419 - loss: 0.7179
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 327us/step - accuracy: 0.5512 - loss: 0.6809
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step - accuracy: 0.5618 - loss: 0.6732
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 330us/step - accuracy: 0.5784 - loss: 0.6659
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 319us/step - accuracy: 0.6095 - loss: 0.6550
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 328us/step - accuracy: 0.6412 - loss: 0.6388
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - accuracy: 0.6768 - loss: 0.6210
# Epoch 8/100
# ...

# %%
print("\n Training Accuracy: %.4f" % (model.evaluate(x_train, y_train )[1]))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.9869 - loss: 0.0480
#
#  Training Accuracy: 0.9931

# %% [markdown]
# 아이리스

# %%
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense 
from sklearn.preprocessing import LabelEncoder

import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np 
import tensorflow as tf
# Seed 값 설정
seed = 0
np.random.seed (seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
df = pd.read_csv('data/iris.csv', names = ["sepal_length", "sepal_width","petal_length"
, "petal_width", "species"])
# 그래프로 확인
# sns.pairplot(df, hue='species');
# plt.show()
# 데이터 분류
dataset = df.values
X = dataset[:, 0:4].astype(float)
Y_obj = dataset[:, 4]
# 문자열을 숫자로 변환
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj) # 선형 데이터
Y_encoded = tf.keras.utils.to_categorical(Y) # 카테고리 데이터

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y_encoded, test_size=0.2, random_state=seed)
print("x_train.shape=", x_train.shape)
print("x_test.shape=", x_test.shape)
print("y_train.shape=", y_train.shape)
print("y_test-shape=", y_test.shape)
# Out:
# x_train.shape= (120, 4)
# x_test.shape= (30, 4)
# y_train.shape= (120, 3)
# y_test-shape= (30, 3)

# %%
# 모델의 설정
model = Sequential()
model.add(Dense(24, input_dim=4, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(3, activation='softmax'))
# 모델 컴파일
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 모델 실행

model.fit(x_train, y_train, epochs=100)
# 결과 출력
print("\n Training Accuracy: %.4f" % (model.evaluate(x_train, y_train )[1]))
print("\n Test Accuracy: %.4f" % (model.evaluate(x_test, y_test )[1]))
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3790 - loss: 1.0419
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.3790 - loss: 0.9768
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - accuracy: 0.3938 - loss: 0.9305
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.4565 - loss: 0.9060
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.5910 - loss: 0.8862
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.6871 - loss: 0.8656
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - accuracy: 0.6871 - loss: 0.8437
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6871 - loss: 0.8215
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.6871 - loss: 0.7996
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - accuracy: 0.6871 - loss: 0.7774
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - accuracy: 0.6871 - loss: 0.7554
# Epoch 12/100
# ...

# %%
model.fit(x_train, y_train, epochs=300)
# 결과 출력
print("\n Training Accuracy: %.4f" % (model.evaluate(x_train, y_train )[1]))
print("\n Test Accuracy: %.4f" % (model.evaluate(x_test, y_test )[1]))
# Out:
# Epoch 1/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9704 - loss: 0.0959
# Epoch 2/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - accuracy: 0.9704 - loss: 0.0959
# Epoch 3/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - accuracy: 0.9704 - loss: 0.0958
# Epoch 4/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9704 - loss: 0.0958
# Epoch 5/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9704 - loss: 0.0957
# Epoch 6/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - accuracy: 0.9704 - loss: 0.0957
# Epoch 7/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - accuracy: 0.9704 - loss: 0.0956
# Epoch 8/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - accuracy: 0.9704 - loss: 0.0955
# Epoch 9/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.9704 - loss: 0.0955
# Epoch 10/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9704 - loss: 0.0954
# Epoch 11/300
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - accuracy: 0.9619 - loss: 0.0954
# Epoch 12/300
# ...

# %% [markdown]
# 에폭 수가 달라도 정확도가 비슷하게 나옴. data가 겹치는 부분이 적어서임

# %%
from tensorflow.keras.models import load_model

# %%
model.save('my_model.keras') # Use keras instead of h5 to remove warnings
del model

# %%
model = load_model('my_model.keras')
print("\n Test Accuracy: %.4f" % (model.evaluate(x_test, y_test )[1]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 1.0000 - loss: 0.0177
#
#  Test Accuracy: 1.0000
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 14 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
