# %%
import tensorflow as tf
import sys 
import os
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt 
import numpy as np
import cv2
model = load_model('model/14-0.3505.keras')
#model = load_model('/content/model_cnn/15-0.0595.hdf5')#colab₫ 79
model.summary
# Out:
# <bound method Model.summary of <Sequential name=sequential_1, built=True>>

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
from glob import glob
import pathlib
img_path = 'My_fashion_mnist'
file_list = glob(img_path + "/*")

for pic in file_list:
    test_num = cv2.imread(pic)
    test_num = cv2.cvtColor(test_num, cv2.COLOR_BGR2GRAY)
    test_num = 255 - test_num
    plt. imshow(test_num, cmap='Greys');
    plt.show()

    test_num = test_num.reshape(1, 784).astype('float64') / 255
    test_predict = model.predict(test_num, verbose=0)
    name = pathlib.Path(pic).stem
    print( 'The Answer of', name ,'is', class_names[test_predict.argmax()])
# Out:
# The Answer of 2 is Trouser
# The Answer of 3 is Coat
# The Answer of 1 is T-shirt/top
