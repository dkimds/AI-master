# %% [markdown]
# # RNN에서 Seq2Seq로, 그리고 어텐션 메커니즘

# %%
import numpy as np 
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding 
from tensorflow.keras.layers import Bidirectional 
from tensorflow.keras.layers import LSTM, Input, Concatenate
from tensorflow.keras.layers import Dense, Dot, Activation
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping

cal_len = 15
# 문자와 인덱스 매핑
chars = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
num_classes = len(chars)

char_to_index = {char: idx for idx, char in enumerate(chars)}
index_to_char = {idx: char for idx, char in enumerate(chars)}
# 데이터 생성 함수
def generate_data(num_samples):
    X = []
    y = []
    for _ in range(num_samples):
        sequence = np.random.choice(list(chars), cal_len)
        X.append([char_to_index[char] for char in sequence]) 
        y.append([char_to_index[char] for char in sequence[::-1]])
    return np.array(X), np.array(y)

# 학습 데이터 생성
num_samples = 20000
X, y = generate_data(num_samples)

# Reshape data
X = X.reshape((X.shape[0], X.shape[1], 1))
y = y.reshape((y.shape[0], y.shape[1], 1))

# %%
# 인코더 정의
encoder_inputs = Input(shape=(cal_len, 1))
encoder = LSTM(128, return_sequences=True,return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

# 디코더 정의
decoder_inputs = Input(shape=(cal_len, 1))
decoder_lstm = LSTM(128, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)

# %%
attention = Dot(axes=[2, 2])([decoder_outputs, encoder_outputs])
attention = Activation('softmax')(attention)
context = Dot(axes=[2, 1])([attention, encoder_outputs])

decoder_combined_context = Concatenate(axis=-1)([decoder_outputs, context])

decoder_dense = Dense(52, activation='softmax')
decoder_outputs = decoder_dense(decoder_combined_context)

# %%
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 입력 데이터와 타겟 데이터를 동일하게 맞춤
decoder_input_data = np.zeros_like(X)

# %%
# EarlyStopping 콜백 정의
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit([X, decoder_input_data], y, epochs=50, validation_split=0.2, callbacks=[early_stopping])

def predict_reverse(input_sequence):
    input_sequence = np.array([char_to_index[char] for char in input_sequence]).reshape((1, cal_len, 1))    
    decoder_input = np.zeros((1, cal_len, 1))
    predicted_sequence = model.predict ([input_sequence, decoder_input])
    predicted_indices = np.argmax(predicted_sequence, axis=-1). reshape((cal_len,))
    return "".join([index_to_char[idx] for idx in predicted_indices])
    # return np.argmax(predicted_sequence, axis=-1). reshape((10,))

#검증용 문자열 리스트 (5글자짜리 30개)
test_strings = ["".join(np.random.choice(list(chars), cal_len)) for _ in range(30)]
# 실제 거꾸로 된 문자열 리스트
expected_outputs = [s[::-1] for s in test_strings]
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.0402 - loss: 3.7954 - val_accuracy: 0.1685 - val_loss: 2.7649
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.2247 - loss: 2.5278 - val_accuracy: 0.3411 - val_loss: 2.0581
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.4032 - loss: 1.9537 - val_accuracy: 0.4991 - val_loss: 1.7005
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.5213 - loss: 1.6358 - val_accuracy: 0.5681 - val_loss: 1.4691
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6123 - loss: 1.4164 - val_accuracy: 0.6638 - val_loss: 1.2855
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6774 - loss: 1.2521 - val_accuracy: 0.7132 - val_loss: 1.1531
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.7231 - loss: 1.1189 - val_accuracy: 0.7547 - val_loss: 1.0368
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7650 - loss: 1.0128 - val_accuracy: 0.7796 - val_loss: 0.9462
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.7992 - loss: 0.9208 - val_accuracy: 0.8046 - val_loss: 0.8751
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8187 - loss: 0.8504 - val_accuracy: 0.8283 - val_loss: 0.8053
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8409 - loss: 0.7831 - val_accuracy: 0.8270 - val_loss: 0.7560
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8571 - loss: 0.7297 - val_accuracy: 0.8542 - val_loss: 0.6935
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8723 - loss: 0.6783 - val_accuracy: 0.8837 - val_loss: 0.6452
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8833 - loss: 0.6355 - val_accuracy: 0.8955 - val_loss: 0.6079
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8955 - loss: 0.5950 - val_accuracy: 0.9046 - val_loss: 0.5759
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9020 - loss: 0.5628 - val_accuracy: 0.8842 - val_loss: 0.5650
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9093 - loss: 0.5304 - val_accuracy: 0.9193 - val_loss: 0.5070
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9194 - loss: 0.4971 - val_accuracy: 0.9134 - val_loss: 0.4879
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9236 - loss: 0.4728 - val_accuracy: 0.9276 - val_loss: 0.4583
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9290 - loss: 0.4481 - val_accuracy: 0.9314 - val_loss: 0.4392
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9323 - loss: 0.4265 - val_accuracy: 0.9260 - val_loss: 0.4178
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9360 - loss: 0.4079 - val_accuracy: 0.9491 - val_loss: 0.3859
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.9479 - loss: 0.3787 - val_accuracy: 0.9525 - val_loss: 0.3675
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9478 - loss: 0.3627 - val_accuracy: 0.9502 - val_loss: 0.3513
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9512 - loss: 0.3448 - val_accuracy: 0.9449 - val_loss: 0.3441
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9489 - loss: 0.3359 - val_accuracy: 0.9540 - val_loss: 0.3254
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9563 - loss: 0.3148 - val_accuracy: 0.9516 - val_loss: 0.3127
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9566 - loss: 0.3027 - val_accuracy: 0.9623 - val_loss: 0.2935
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.6826 - loss: 1.8304 - val_accuracy: 0.8640 - val_loss: 0.5947
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.8745 - loss: 0.5755 - val_accuracy: 0.8850 - val_loss: 0.5382
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8980 - loss: 0.5228 - val_accuracy: 0.9113 - val_loss: 0.4964
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9092 - loss: 0.4823 - val_accuracy: 0.9112 - val_loss: 0.4418
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9185 - loss: 0.4224 - val_accuracy: 0.9220 - val_loss: 0.3875

# %%
correct_predictions = 0
total_predictions = len(test_strings)

for i, test_string in enumerate(test_strings):
    predicted_output = predict_reverse(test_string)
    is_correct = predicted_output == expected_outputs[i]
    
    if is_correct:
        correct_predictions += 1
        
    print(f"입력: {test_string}")
    print(f"예측된 출력: {predicted_output}")
    print(f"실제 출력: {expected_outputs[i]}")
    print(f"정확 여부: {'맞음' if is_correct else '틀림'}\n")

accuracy = correct_predictions / total_predictions
print(f"총 정확도: {accuracy * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 입력: NLpiqEZBCKuDUzc
# 예측된 출력: bzUDuKCBZEqipLO
# 실제 출력: czUDuKCBZEqipLN
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 입력: iYDkLgFpnZbEdBx
# 예측된 출력: xBdEbZnpFgLkDYi
# 실제 출력: xBdEbZnpFgLkDYi
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 입력: cCLFTdOBhsSvmMP
# 예측된 출력: PMmvSshBOdTFLCc
# 실제 출력: PMmvSshBOdTFLCc
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 입력: AwUlYgXMlmUChQx
# 예측된 출력: yQhCUmlMXgYlUwA
# 실제 출력: xQhCUmlMXgYlUwA
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 입력: FLkDwDwfSQuunpg
# 예측된 출력: gpnuvQSfwDwDkLF
# 실제 출력: gpnuuQSfwDwDkLF
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 입력: jMtiDVrtEAhznPf
# 예측된 출력: fPnzhAEtrVDitMj
# 실제 출력: fPnzhAEtrVDitMj
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: snrHyFScLOMlvdg
# 예측된 출력: gdvlMOLcSFyHrnt
# 실제 출력: gdvlMOLcSFyHrns
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: HcprloYkBqUEbFp
# 예측된 출력: pFbEUqBkYolrpcG
# 실제 출력: pFbEUqBkYolrpcH
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: NHyYxKTkrJNwTuq
# 예측된 출력: quTwNJrkTKxYyHN
# 실제 출력: quTwNJrkTKxYyHN
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: nenwONUXIybLhqs
# 예측된 출력: sqhLbyIXUNOwneo
# 실제 출력: sqhLbyIXUNOwnen
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: aYuuvLbXigdYvMY
# 예측된 출력: YMvYdgiXbLvuuYa
# 실제 출력: YMvYdgiXbLvuuYa
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: JWqCfvqaMCBBYQp
# 예측된 출력: pQYBBCMaqvfCqWJ
# 실제 출력: pQYBBCMaqvfCqWJ
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: REGKeKuQvsEPUCw
# 예측된 출력: wCUPEtvQuKeKGER
# 실제 출력: wCUPEsvQuKeKGER
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 입력: sAMEniNjbBLYOCp
# 예측된 출력: pCOYLBbjNinEMAs
# 실제 출력: pCOYLBbjNinEMAs
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 입력: dDBQsXedkIDPkuY
# 예측된 출력: YukPDIkdeXsQBDd
# 실제 출력: YukPDIkdeXsQBDd
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: MOFFdyOVahJqPys
# 예측된 출력: syPqJhaVOxdFFOL
# 실제 출력: syPqJhaVOydFFOM
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: CKudCNToUPLqwSu
# 예측된 출력: uSwqLPUoTNCdvKC
# 실제 출력: uSwqLPUoTNCduKC
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: iftJXjihIyAHdqP
# 예측된 출력: PqdHAyIhijXJtfi
# 실제 출력: PqdHAyIhijXJtfi
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: TqwvaRwRDSiFwmD
# 예측된 출력: DmwFiSDRwRavwqT
# 실제 출력: DmwFiSDRwRavwqT
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: jVZwcGgnfiBNNxi
# 예측된 출력: ixNNBifngGcwZVj
# 실제 출력: ixNNBifngGcwZVj
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: uurBZCMcrFcumZE
# 예측된 출력: EZmucFscMCZBquu
# 실제 출력: EZmucFrcMCZBruu
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: GGEGKrYwUTWMWjs
# 예측된 출력: sjWMWTUwYrKGEGG
# 실제 출력: sjWMWTUwYrKGEGG
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: kFMBeOAnXgXGoog
# 예측된 출력: gooGXgXnAOeBMFk
# 실제 출력: gooGXgXnAOeBMFk
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 입력: keAigGVtJfpfNXB
# 예측된 출력: BXNfpfJuVGgiAek
# 실제 출력: BXNfpfJtVGgiAek
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 입력: jPvIEZesFuqXbPR
# 예측된 출력: RPbXquFseZEIvPj
# 실제 출력: RPbXquFseZEIvPj
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: GBxcugZxSJQBrzN
# 예측된 출력: NzrBQJSxZgucwBG
# 실제 출력: NzrBQJSxZgucxBG
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: EBRXbdmEzFRUCwi
# 예측된 출력: iwCURFzEmdbXRBE
# 실제 출력: iwCURFzEmdbXRBE
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: tQtFqiQZqEKBezx
# 예측된 출력: yzeBKEqZQiqFtQt
# 실제 출력: xzeBKEqZQiqFtQt
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: PyHCKgYFPPAtAAS
# 예측된 출력: SAAtAPPFYgKCHzP
# 실제 출력: SAAtAPPFYgKCHyP
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: gDuVFqvNdOosNKr
# 예측된 출력: rKNsoOdNvqFVuDg
# 실제 출력: rKNsoOdNvqFVuDg
# 정확 여부: 맞음
#
# 총 정확도: 53.33%

# %% [markdown]
# ![image.png](attachment:image.png)
