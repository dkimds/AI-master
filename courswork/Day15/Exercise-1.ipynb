# %% [markdown]
# # RNN에서 Seq2Seq로, 그리고 어텐션 메커니즘 + 임베이딩

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding, Dot, Activation, Concatenate
from tensorflow.keras.callbacks import EarlyStopping

cal_len = 15
# 문자와 인덱스 매핑
chars = 'ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz'
num_classes = len(chars)

char_to_index = {char: idx for idx, char in enumerate(chars)}
index_to_char = {idx: char for idx, char in enumerate(chars)}
# 데이터 생성 함수
def generate_data(num_samples):
    X = []
    y = []
    for _ in range(num_samples):
        sequence = np.random.choice(list(chars), cal_len)
        X.append([char_to_index[char] for char in sequence]) 
        y.append([char_to_index[char] for char in sequence[::-1]])
    return np.array(X), np.array(y)

# 학습 데이터 생성
num_samples = 20000
X, y = generate_data(num_samples)

# %%
# 인코더 정의
encoder_inputs = Input(shape=(cal_len, 1))
# 임베딩 추가
encoder_embedding = Embedding(input_dim=num_classes, output_dim=64, input_length=cal_len)(encoder_inputs)
encoder = LSTM(128, return_sequences=True,return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
encoder_states = [state_h, state_c]

# 디코더 정의
decoder_inputs = Input(shape=(cal_len, 1))
# 임베딩 추가
decoder_embedding = Embedding(input_dim=num_classes, output_dim=64, input_length=cal_len)(decoder_inputs)
decoder_lstm = LSTM(128, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)

# 어텐션
attention = Dot(axes=[2, 2])([decoder_outputs, encoder_outputs])
attention = Activation('softmax')(attention)
context = Dot(axes=[2, 1])([attention, encoder_outputs])

# 디코더 출려과 컨텍스트 결합
decoder_combined_context = Concatenate(axis=-1)([decoder_outputs, context])

# 출력 레이어
decoder_dense = Dense(52, activation='softmax')
decoder_outputs = decoder_dense(decoder_combined_context)

# 모데정의
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# 입력 데이터와 타겟 데이터를 동일하게 맞춤
decoder_input_data = np.zeros_like(X)

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

model.fit([X, decoder_input_data], y, epochs=50, validation_split=0.2, callbacks=[early_stopping])

def predict_reverse(input_sequence):
    input_sequence = np.array([char_to_index[char] for char in input_sequence]).reshape((1, cal_len, 1))    
    decoder_input = np.zeros((1, cal_len, 1))
    predicted_sequence = model.predict ([input_sequence, decoder_input])
    predicted_indices = np.argmax(predicted_sequence, axis=-1). reshape((cal_len,))
    return "".join([index_to_char[idx] for idx in predicted_indices])
    # return np.argmax(predicted_sequence, axis=-1). reshape((10,))
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.0387 - loss: 3.8063 - val_accuracy: 0.1409 - val_loss: 2.8689
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.1929 - loss: 2.6396 - val_accuracy: 0.3265 - val_loss: 2.1754
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.3480 - loss: 2.1275 - val_accuracy: 0.4213 - val_loss: 1.8770
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.4691 - loss: 1.8036 - val_accuracy: 0.5415 - val_loss: 1.6220
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.5618 - loss: 1.5672 - val_accuracy: 0.6031 - val_loss: 1.4370
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.6317 - loss: 1.3820 - val_accuracy: 0.6947 - val_loss: 1.2643
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.6866 - loss: 1.2431 - val_accuracy: 0.7157 - val_loss: 1.1614
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.7237 - loss: 1.1469 - val_accuracy: 0.7136 - val_loss: 1.1707
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.7393 - loss: 1.1237 - val_accuracy: 0.7691 - val_loss: 1.0425
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.7806 - loss: 1.0137 - val_accuracy: 0.7939 - val_loss: 0.9424
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8113 - loss: 0.9183 - val_accuracy: 0.8183 - val_loss: 0.8654
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 13ms/step - accuracy: 0.8339 - loss: 0.8442 - val_accuracy: 0.8121 - val_loss: 0.8064
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8574 - loss: 0.7792 - val_accuracy: 0.8856 - val_loss: 0.7359
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8753 - loss: 0.7267 - val_accuracy: 0.8565 - val_loss: 0.6920
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8872 - loss: 0.6780 - val_accuracy: 0.8948 - val_loss: 0.6464
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8984 - loss: 0.6363 - val_accuracy: 0.8984 - val_loss: 0.6148
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.9107 - loss: 0.5980 - val_accuracy: 0.9075 - val_loss: 0.5804
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9184 - loss: 0.5611 - val_accuracy: 0.9087 - val_loss: 0.5371
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9288 - loss: 0.5223 - val_accuracy: 0.9313 - val_loss: 0.5006
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9394 - loss: 0.4918 - val_accuracy: 0.9414 - val_loss: 0.4746
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9439 - loss: 0.4626 - val_accuracy: 0.9446 - val_loss: 0.4485
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9459 - loss: 0.4389 - val_accuracy: 0.9458 - val_loss: 0.4264
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9511 - loss: 0.4126 - val_accuracy: 0.9597 - val_loss: 0.3934
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9541 - loss: 0.3915 - val_accuracy: 0.9641 - val_loss: 0.3734
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9635 - loss: 0.3678 - val_accuracy: 0.9562 - val_loss: 0.3682
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9610 - loss: 0.3543 - val_accuracy: 0.9717 - val_loss: 0.3346
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9675 - loss: 0.3314 - val_accuracy: 0.9578 - val_loss: 0.3262
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9699 - loss: 0.3142 - val_accuracy: 0.9703 - val_loss: 0.3036
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9710 - loss: 0.2983 - val_accuracy: 0.9815 - val_loss: 0.2808
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9738 - loss: 0.2813 - val_accuracy: 0.9797 - val_loss: 0.2678
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9757 - loss: 0.2673 - val_accuracy: 0.9807 - val_loss: 0.2533
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9796 - loss: 0.2514 - val_accuracy: 0.9843 - val_loss: 0.2399
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9812 - loss: 0.2389 - val_accuracy: 0.9812 - val_loss: 0.2296
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9795 - loss: 0.2295 - val_accuracy: 0.9811 - val_loss: 0.2179
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9850 - loss: 0.2121 - val_accuracy: 0.9924 - val_loss: 0.2025
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9805 - loss: 0.2070 - val_accuracy: 0.9839 - val_loss: 0.1978
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9891 - loss: 0.1884 - val_accuracy: 0.9617 - val_loss: 0.2082
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9858 - loss: 0.1823 - val_accuracy: 0.9938 - val_loss: 0.1683
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9878 - loss: 0.1719 - val_accuracy: 0.9807 - val_loss: 0.1732
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9827 - loss: 0.1686 - val_accuracy: 0.9918 - val_loss: 0.1565
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9877 - loss: 0.1571 - val_accuracy: 0.9924 - val_loss: 0.1468
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9905 - loss: 0.1450 - val_accuracy: 0.9951 - val_loss: 0.1344
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9934 - loss: 0.1338 - val_accuracy: 0.9814 - val_loss: 0.1471
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9901 - loss: 0.1332 - val_accuracy: 0.9928 - val_loss: 0.1243
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9927 - loss: 0.1230 - val_accuracy: 0.9957 - val_loss: 0.1150
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9924 - loss: 0.1202 - val_accuracy: 0.9886 - val_loss: 0.1202
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9947 - loss: 0.1091 - val_accuracy: 0.9950 - val_loss: 0.1085
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9916 - loss: 0.1086 - val_accuracy: 0.9614 - val_loss: 0.1542
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9940 - loss: 0.1008 - val_accuracy: 0.9518 - val_loss: 0.1826
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9878 - loss: 0.1073 - val_accuracy: 0.9970 - val_loss: 0.0912

# %%
#검증용 문자열 리스트 (5글자짜리 30개)
test_strings = ["".join(np.random.choice(list(chars), cal_len)) for _ in range(30)]
# 실제 거꾸로 된 문자열 리스트
expected_outputs = [s[::-1] for s in test_strings]

correct_predictions = 0
total_predictions = len(test_strings)

for i, test_string in enumerate(test_strings):
    predicted_output = predict_reverse(test_string)
    is_correct = predicted_output == expected_outputs[i]
    
    if is_correct:
        correct_predictions += 1
        
    print(f"입력: {test_string}")
    print(f"예측된 출력: {predicted_output}")
    print(f"실제 출력: {expected_outputs[i]}")
    print(f"정확 여부: {'맞음' if is_correct else '틀림'}\n")

accuracy = correct_predictions / total_predictions
print(f"총 정확도: {accuracy * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 입력: RYblxIucAvmbJyO
# 예측된 출력: OyJbmvAcuIxlbYR
# 실제 출력: OyJbmvAcuIxlbYR
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: eEyxTvejxyikkNa
# 예측된 출력: aNkkiyxjevTxyEe
# 실제 출력: aNkkiyxjevTxyEe
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: JIqaZfyeZOXCJfT
# 예측된 출력: TfJCXOZeyfZaqIJ
# 실제 출력: TfJCXOZeyfZaqIJ
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 입력: uMtFEVCYMifTKXY
# 예측된 출력: YXKTfiMYCVEFtMu
# 실제 출력: YXKTfiMYCVEFtMu
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: PZgsdWBgfHYfvCU
# 예측된 출력: UCvfYHfgBWdsgZP
# 실제 출력: UCvfYHfgBWdsgZP
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: dRDsoycCUkHfPpU
# 예측된 출력: UpPfHkUCcyosDRd
# 실제 출력: UpPfHkUCcyosDRd
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: IETEHBFEhqFVoFR
# 예측된 출력: RFoVFqhEFBHETEI
# 실제 출력: RFoVFqhEFBHETEI
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: AbJavjAICsDKdPL
# 예측된 출력: LPdKDsCIAjvaJaA
# 실제 출력: LPdKDsCIAjvaJbA
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: jBwMdZmCUkcUvqM
# 예측된 출력: MqvUckUCmZdMwBj
# 실제 출력: MqvUckUCmZdMwBj
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: eRgJXDZanXdCdcA
# 예측된 출력: AcdCdXnaZDXJgRe
# 실제 출력: AcdCdXnaZDXJgRe
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: MgkpjWHwIafuMod
# 예측된 출력: doMufaIwHWjpkgM
# 실제 출력: doMufaIwHWjpkgM
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: IfhILqYRIQHQWRH
# 예측된 출력: HRWQHQIRYqLIhfI
# 실제 출력: HRWQHQIRYqLIhfI
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: uDeHnpXOdoXamwa
# 예측된 출력: awmaXodOXpnHeDu
# 실제 출력: awmaXodOXpnHeDu
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: APvDCAMxeYTtloX
# 예측된 출력: XoltTYexMACDvPA
# 실제 출력: XoltTYexMACDvPA
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: zUSLxrTCtOrWSqp
# 예측된 출력: pqSWrOtCTrxLSUz
# 실제 출력: pqSWrOtCTrxLSUz
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: LPnCXNeXrERvGkb
# 예측된 출력: bkGvRErXeNXCnPL
# 실제 출력: bkGvRErXeNXCnPL
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: RMWBUEJUYbNODMq
# 예측된 출력: qMDONbYUJEUBWMR
# 실제 출력: qMDONbYUJEUBWMR
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: dDoaNZELjoIdCVT
# 예측된 출력: TVCdIojLEZNaoDd
# 실제 출력: TVCdIojLEZNaoDd
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: BFQcjYMfQzPKdvY
# 예측된 출력: YvdKPzQfMYjcQFB
# 실제 출력: YvdKPzQfMYjcQFB
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: CwtMaxDDeJBtIAE
# 예측된 출력: EAItBJeDDxaMtvC
# 실제 출력: EAItBJeDDxaMtwC
# 정확 여부: 틀림
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: wRSVZMuZuPFfQku
# 예측된 출력: ukQfFPuZuMZVSRw
# 실제 출력: ukQfFPuZuMZVSRw
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: cIumLzsdlOoIPaZ
# 예측된 출력: ZaPIoOldszLmuIc
# 실제 출력: ZaPIoOldszLmuIc
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 입력: qmMdTMEtizHXGnH
# 예측된 출력: HnGXHzitEMTdMmq
# 실제 출력: HnGXHzitEMTdMmq
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: lPNkHPGuSZeDJlw
# 예측된 출력: wlJDeZSuGPHkNPl
# 실제 출력: wlJDeZSuGPHkNPl
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: FABlbdZnINntxJo
# 예측된 출력: oJxtnNInZdblBAF
# 실제 출력: oJxtnNInZdblBAF
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: GITPzDSSfvXUAWY
# 예측된 출력: YWAUXvfSSDzPTIG
# 실제 출력: YWAUXvfSSDzPTIG
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 입력: cABzpwNHXjWIJwA
# 예측된 출력: AwJIWjXHNwpzBAc
# 실제 출력: AwJIWjXHNwpzBAc
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 입력: zUnflYttBueoJoY
# 예측된 출력: YoJoeuBttYlfnUz
# 실제 출력: YoJoeuBttYlfnUz
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 입력: iBxeJnVuxXnTNvp
# 예측된 출력: pvNTnXxuVnJexBi
# 실제 출력: pvNTnXxuVnJexBi
# 정확 여부: 맞음
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 입력: KLzJroUUrnLrpPl
# 예측된 출력: lPprLnrUUorJzLK
# 실제 출력: lPprLnrUUorJzLK
# 정확 여부: 맞음
#
# 총 정확도: 93.33%
